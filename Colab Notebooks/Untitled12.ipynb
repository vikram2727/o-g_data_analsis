# %%
pip install PyLTI1p3
# Out:
# Requirement already satisfied: PyLTI1p3 in /usr/local/lib/python3.6/dist-packages (1.8.1)
# Requirement already satisfied: jwcrypto in /usr/local/lib/python3.6/dist-packages (from PyLTI1p3) (0.8)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from PyLTI1p3) (2.23.0)
# Requirement already satisfied: pyjwt>=1.5 in /usr/local/lib/python3.6/dist-packages (from PyLTI1p3) (1.7.1)
# Requirement already satisfied: typing in /usr/local/lib/python3.6/dist-packages (from PyLTI1p3) (3.7.4.3)
# Requirement already satisfied: cryptography>=2.3 in /usr/local/lib/python3.6/dist-packages (from jwcrypto->PyLTI1p3) (3.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->PyLTI1p3) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->PyLTI1p3) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->PyLTI1p3) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->PyLTI1p3) (2.10)
# Requirement already satisfied: six>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from cryptography>=2.3->jwcrypto->PyLTI1p3) (1.15.0)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in /usr/local/lib/python3.6/dist-packages (from cryptography>=2.3->jwcrypto->PyLTI1p3) (1.14.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.3->jwcrypto->PyLTI1p3) (2.20)

# %%
pip install segpy
# Out:
# Requirement already satisfied: segpy in /usr/local/lib/python3.6/dist-packages (2.0.4)
# Requirement already satisfied: docopt-subcommands in /usr/local/lib/python3.6/dist-packages (from segpy) (4.0.0)
# Requirement already satisfied: stevedore in /usr/local/lib/python3.6/dist-packages (from segpy) (3.2.2)
# Requirement already satisfied: docopt in /usr/local/lib/python3.6/dist-packages (from docopt-subcommands->segpy) (0.6.2)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from stevedore->segpy) (5.5.0)
# Requirement already satisfied: importlib-metadata>=1.7.0; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from stevedore->segpy) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=1.7.0; python_version < "3.8"->stevedore->segpy) (3.2.0)

# %%
from segpy.reader import create_reader
from segpy.writer import write_segy

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b67ac8e2-805a-4328-bb4b-a9ee07c4965a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b67ac8e2-805a-4328-bb4b-a9ee07c4965a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving SEGY2 to SEGY2

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f3813188-245c-4ea0-8887-55ea6dbbcfec" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f3813188-245c-4ea0-8887-55ea6dbbcfec">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving VSPNI_COMPUTED_12.SEGY to VSPNI_COMPUTED_12.SEGY

# %%
with open('VSPNI_COMPUTED_12.SEGY', 'rb') as segy_in_file:
    seg_y_dataset = create_reader(segy_in_file, endian='<')
    print(seg_y_dataset.num_traces())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/segpy/header.py in __set__(self, instance, value)
#     298         try:
# --> 299             self._instance_data[instance] = self._named_field._value_type(value)
#     300         except ValueError as e:
#
# /usr/local/lib/python3.6/dist-packages/segpy/field_types.py in class_new(cls, *args, **kwargs)
#      13                 cls.__name__, instance,
# ---> 14                 cls.MINIMUM, cls.MAXIMUM))
#      15         return instance
#
# ValueError: NNInt16 value 59395 outside range 0 to 32767
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-4c6afcf4daf8> in <module>()
#       1 with open('VSPNI_COMPUTED_12.SEGY', 'rb') as segy_in_file:
# ----> 2     seg_y_dataset = create_reader(segy_in_file, endian='<')
#       3     print(seg_y_dataset.num_traces())
#
# /usr/local/lib/python3.6/dist-packages/segpy/reader.py in create_reader(fh, encoding, binary_reel_header_format, trace_header_format, endian, progress, cache_directory, dimensionality)
#     151     if reader is None:
#     152         reader = _make_reader(fh, encoding, binary_reel_header_format, trace_header_format,
# --> 153                               endian, progress_callback, dimensionality)
#     154         if cache_file_path is not None:
#     155             _save_reader_to_cache(reader, cache_file_path)
#
# /usr/local/lib/python3.6/dist-packages/segpy/reader.py in _make_reader(fh, encoding, binary_reel_header_format, trace_header_format, endian, progress, dimensionality)
#     256         encoding = ASCII
#     257     textual_reel_header = read_textual_reel_header(fh, encoding)
# --> 258     binary_reel_header = read_binary_reel_header(fh, binary_reel_header_format, endian=endian)
#     259     extended_textual_header = read_extended_textual_headers(fh, binary_reel_header, encoding)
#     260     bps = bytes_per_sample(binary_reel_header)
#
# /usr/local/lib/python3.6/dist-packages/segpy/toolkit.py in read_binary_reel_header(fh, binary_reel_header_format, endian)
#     180     header_packer = make_header_packer(binary_reel_header_format, endian)
#     181     buffer = fh.read(binary_reel_header_format.LENGTH_IN_BYTES)
# --> 182     reel_header = header_packer.unpack(buffer)
#     183     return reel_header
#     184
#
# /usr/local/lib/python3.6/dist-packages/segpy/packer.py in unpack(self, buffer)
#     198                                          str(e).capitalize())) from e
#     199         else:
# --> 200             return self._unpack(values)
#     201
#     202     @abstractmethod
#
# /usr/local/lib/python3.6/dist-packages/segpy/packer.py in _unpack(self, values)
#     222
#     223     def _unpack(self, values):
# --> 224         return self._header_format_class(*values)
#     225
#     226
#
# /usr/local/lib/python3.6/dist-packages/segpy/header.py in __init__(self, *args, **kwargs)
#      29         """
#      30         for keyword, arg in zip(self.ordered_field_names(), args):
# ---> 31             setattr(self, keyword, arg)
#      32
#      33         for keyword, arg in kwargs.items():
#
# /usr/local/lib/python3.6/dist-packages/segpy/header.py in __set__(self, instance, value)
#     300         except ValueError as e:
#     301             raise ValueError("Assigned value {!r} for {} attribute must be convertible to {}: {}"
# --> 302                              .format(value, self._name, self._named_field._value_type.__name__, e)) from e
#     303
#     304     def __delete__(self, instance):
#
# ValueError: Assigned value 59395 for sample_interval attribute must be convertible to NNInt16: NNInt16 value 59395 outside range 0 to 32767

# %%
with open('seismic_little.sgy', 'rb') as segy_in_file:
    # The seg_y_dataset is a lazy-reader, so keep the file open throughout.
    seg_y_dataset = create_reader(segy_in_file, endian='<')  # Non-standard Rev 1 little-endian
    print(seg_y_dataset.num_traces())
    # Write the seg_y_dataset out to another file, in big-endian format
    with open('seismic_big.sgy', 'wb') as segy_out_file:
        write_segy(segy_out_file, seg_y_dataset, endian='>')  #  Standard Rev 1 big-endian

# %%
with open('VSPNI_COMPUTED_12.SEGY', 'rb') as segy_in_file:
# Out:
#   File "<ipython-input-10-c879cae3f7f1>", line 1
#     with open('VSPNI_COMPUTED_12.SEGY', 'rb') as segy_in_file:
#                                                               ^
# SyntaxError: unexpected EOF while parsing

# %%
pip install lti
# Out:
# Collecting lti
#   Downloading https://files.pythonhosted.org/packages/4c/fb/3545582f7e2e81134d289e51d91342e016e27a3b56f1a7ed6460e65dfb31/lti-0.9.5-py2.py3-none-any.whl
# Requirement already satisfied: oauthlib in /usr/local/lib/python3.6/dist-packages (from lti) (3.1.0)
# Requirement already satisfied: requests-oauthlib in /usr/local/lib/python3.6/dist-packages (from lti) (1.3.0)
# Requirement already satisfied: lxml in /usr/local/lib/python3.6/dist-packages (from lti) (4.2.6)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib->lti) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->requests-oauthlib->lti) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->requests-oauthlib->lti) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->requests-oauthlib->lti) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->requests-oauthlib->lti) (2.10)
# Installing collected packages: lti
# Successfully installed lti-0.9.5
