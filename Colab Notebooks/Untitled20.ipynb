# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.axes_grid1.axes_divider import make_axes_locatable
from matplotlib.colors import ListedColormap
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7b963ad5-ee1f-4c18-90f7-0a645312cfd5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7b963ad5-ee1f-4c18-90f7-0a645312cfd5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 15_9-19_A_CPI.las to 15_9-19_A_CPI.las

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f71de061-a735-4478-a87c-15571c284c64" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f71de061-a735-4478-a87c-15571c284c64">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 15_9-19_BT2_CPI.las to 15_9-19_BT2_CPI.las

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c256d279-491f-43fb-b8dc-3e56f349ffe5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c256d279-491f-43fb-b8dc-3e56f349ffe5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 15_9-19_SR_CPI.las to 15_9-19_SR_CPI.las

# %%
pip install lasio
# Out:
# Collecting lasio
#   Downloading https://files.pythonhosted.org/packages/5e/8e/ce58a22ec8454a12f92333a50f2add5f6131218c4815952d6ca7cbd578f0/lasio-0.28-py3-none-any.whl
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from lasio) (1.18.5)
# Installing collected packages: lasio
# Successfully installed lasio-0.28

# %%
import lasio

# %%
las1 = lasio.read('15_9-19_A_CPI.las')

# %%
las2 = lasio.read("15_9-19_BT2_CPI.las")

# %%
las3 = lasio.read("15_9-19_SR_CPI.las")

# %%
df3 = las3.df()

# %%
df3.head()
# Out:
#                BWV      DT  KLOGH  KLOGV  PHIF  SAND_FLAG  SW  VSH
# DEPTH
# 3549.7008  0.08183     NaN    NaN    NaN   NaN        NaN NaN  NaN
# 3549.8532  0.08183  54.594    NaN    NaN   NaN        NaN NaN  NaN
# 3550.0056  0.08183  54.594    NaN    NaN   NaN        NaN NaN  NaN
# 3550.1580  0.08183  54.594    NaN    NaN   NaN        NaN NaN  NaN
# 3550.3104  0.08183  54.594    NaN    NaN   NaN        NaN NaN  NaN

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 7013 entries, 3549.7008 to 4618.3296
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   BWV        7012 non-null   float64
#  1   DT         7012 non-null   float64
#  2   KLOGH      6782 non-null   float64
#  3   KLOGV      3865 non-null   float64
#  4   PHIF       6886 non-null   float64
#  5   SAND_FLAG  6886 non-null   float64
#  6   SW         6886 non-null   float64
#  7   VSH        1882 non-null   float64
# dtypes: float64(8)
# memory usage: 493.1 KB

# %%
df1.head()
# Out:
#             BS       BVW  CARB_FLAG  ...   SWIRR      TEMP       VSH
# DEPTH                                ...
# 3666.5916  8.5  0.111705        0.0  ...  1.8023  112.7249  0.598800
# 3666.7440  8.5  0.112236        0.0  ...  7.9467  112.7285  0.599555
# 3666.8964  8.5  0.114825        0.0  ...  6.5907  112.7321  0.600310
# 3667.0488  8.5  0.114419        0.0  ...  8.6274  112.7358  0.601065
# 3667.2012  8.5  0.115867        0.0  ...  6.8473  112.7394  0.601820
#
# [5 rows x 23 columns]

# %%
df2.head()
# Out:
#                 BVW  CARB_FLAG  COAL_FLAG  ...   SW      TEMP     VSH
# DEPTH                                      ...
# 3768.0900  0.034643        0.0        0.0  ...  1.0  113.7916  0.6610
# 3768.2424  0.032957        0.0        0.0  ...  1.0  113.7951  0.6946
# 3768.3948  0.010825        0.0        0.0  ...  1.0  113.7986  0.7812
# 3768.5472  0.017037        0.0        0.0  ...  1.0  113.8022  0.9155
# 3768.6996  0.044282        0.0        0.0  ...  1.0  113.8057  0.9545
#
# [5 rows x 13 columns]

# %%
df3.head()
# Out:
#                BWV      DT  KLOGH  KLOGV  PHIF  SAND_FLAG  SW  VSH
# DEPTH
# 3549.7008  0.08183     NaN    NaN    NaN   NaN        NaN NaN  NaN
# 3549.8532  0.08183  54.594    NaN    NaN   NaN        NaN NaN  NaN
# 3550.0056  0.08183  54.594    NaN    NaN   NaN        NaN NaN  NaN
# 3550.1580  0.08183  54.594    NaN    NaN   NaN        NaN NaN  NaN
# 3550.3104  0.08183  54.594    NaN    NaN   NaN        NaN NaN  NaN
