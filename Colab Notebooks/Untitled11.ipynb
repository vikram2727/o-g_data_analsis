# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-667ad750-590e-4371-906c-c8343856a061" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-667ad750-590e-4371-906c-c8343856a061">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving well log.xlsx to well log.xlsx

# %%
df = pd.read_excel("well log.xlsx")

# %%
df.head()
# Out:
#    #Depth     BVW  COAL_FLAG    PHIF  SAND_FLAG   SW   VCARB     VSH   KLOGH
# 0  3319.7  0.0200          0  0.0200          0  1.0  0.0120  0.7446  0.0010
# 1  3319.8  0.0200          0  0.0200          0  1.0  0.0000  0.7582  0.0010
# 2  3319.9  0.0200          0  0.0200          0  1.0  0.0339  0.5477  0.0017
# 3  3320.0  0.0238          0  0.0238          0  1.0  0.1487  0.4117  0.0306
# 4  3320.1  0.0413          0  0.0413          0  1.0  0.1526  0.3592  0.1252

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2872 entries, 0 to 2871
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   #Depth     2872 non-null   float64
#  1   BVW        2872 non-null   float64
#  2   COAL_FLAG  2872 non-null   int64
#  3   PHIF       2872 non-null   float64
#  4   SAND_FLAG  2872 non-null   int64
#  5   SW         2872 non-null   float64
#  6   VCARB      2872 non-null   float64
#  7   VSH        2872 non-null   float64
#  8   KLOGH      2872 non-null   float64
# dtypes: float64(7), int64(2)
# memory usage: 202.1 KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       #Depth     BVW  COAL_FLAG    PHIF  SAND_FLAG   SW   VCARB     VSH   KLOGH
# 0     3319.7  0.0200          0  0.0200          0  1.0  0.0120  0.7446  0.0010
# 1     3319.8  0.0200          0  0.0200          0  1.0  0.0000  0.7582  0.0010
# 2     3319.9  0.0200          0  0.0200          0  1.0  0.0339  0.5477  0.0017
# 3     3320.0  0.0238          0  0.0238          0  1.0  0.1487  0.4117  0.0306
# 4     3320.1  0.0413          0  0.0413          0  1.0  0.1526  0.3592  0.1252
# ...      ...     ...        ...     ...        ...  ...     ...     ...     ...
# 2867  3606.4  0.0308          0  0.0308          0  1.0  0.0000  0.8386  0.0010
# 2868  3606.5  0.0301          0  0.0301          0  1.0  0.0000  0.8195  0.0010
# 2869  3606.6  0.0312          0  0.0312          0  1.0  0.0000  0.8195  0.0010
# 2870  3606.7  0.0341          0  0.0341          0  1.0  0.0000  0.8202  0.0010
# 2871  3606.8  0.0370          0  0.0370          0  1.0  0.0000  0.8035  0.0010
#
# [2872 rows x 9 columns]>

# %%
df.keys()
# Out:
# Index(['#Depth', 'BVW', 'COAL_FLAG', 'PHIF', 'SAND_FLAG', 'SW', 'VCARB', 'VSH',
#        'KLOGH'],
#       dtype='object')

# %%
print(df.iloc[4, 3])
# Out:
# 0.0413

# %%
c = df.iloc[:,:-1]
c
# Out:
#       #Depth     BVW  COAL_FLAG    PHIF  SAND_FLAG   SW   VCARB     VSH
# 0     3319.7  0.0200          0  0.0200          0  1.0  0.0120  0.7446
# 1     3319.8  0.0200          0  0.0200          0  1.0  0.0000  0.7582
# 2     3319.9  0.0200          0  0.0200          0  1.0  0.0339  0.5477
# 3     3320.0  0.0238          0  0.0238          0  1.0  0.1487  0.4117
# 4     3320.1  0.0413          0  0.0413          0  1.0  0.1526  0.3592
# ...      ...     ...        ...     ...        ...  ...     ...     ...
# 2867  3606.4  0.0308          0  0.0308          0  1.0  0.0000  0.8386
# 2868  3606.5  0.0301          0  0.0301          0  1.0  0.0000  0.8195
# 2869  3606.6  0.0312          0  0.0312          0  1.0  0.0000  0.8195
# 2870  3606.7  0.0341          0  0.0341          0  1.0  0.0000  0.8202
# 2871  3606.8  0.0370          0  0.0370          0  1.0  0.0000  0.8035
#
# [2872 rows x 8 columns]

# %%
y = df.iloc[:, -1].values
y
# Out:
# array([0.001 , 0.001 , 0.0017, ..., 0.001 , 0.001 , 0.001 ])

# %%
from sklearn import preprocessing
import numpy as np
scaler = preprocessing.StandardScaler()

# %%
x_array = np.array(df['KLOGH'])
normalized_X = preprocessing.normalize([x_array])

# %%
normalized_X
# Out:
# array([[3.84884311e-07, 3.84884311e-07, 6.54303328e-07, ...,
#         3.84884311e-07, 3.84884311e-07, 3.84884311e-07]])

# %%
y=normalized_X

# %%
scaler = preprocessing.StandardScaler()

# %%
scaled_df = scaler.fit_transform(df)
scaled_df = pd.DataFrame(scaled_df, columns=KLOGH)

# %%
X = c

# %%
X
# Out:
#       #Depth     BVW  COAL_FLAG    PHIF  SAND_FLAG   SW   VCARB     VSH
# 0     3319.7  0.0200          0  0.0200          0  1.0  0.0120  0.7446
# 1     3319.8  0.0200          0  0.0200          0  1.0  0.0000  0.7582
# 2     3319.9  0.0200          0  0.0200          0  1.0  0.0339  0.5477
# 3     3320.0  0.0238          0  0.0238          0  1.0  0.1487  0.4117
# 4     3320.1  0.0413          0  0.0413          0  1.0  0.1526  0.3592
# ...      ...     ...        ...     ...        ...  ...     ...     ...
# 2867  3606.4  0.0308          0  0.0308          0  1.0  0.0000  0.8386
# 2868  3606.5  0.0301          0  0.0301          0  1.0  0.0000  0.8195
# 2869  3606.6  0.0312          0  0.0312          0  1.0  0.0000  0.8195
# 2870  3606.7  0.0341          0  0.0341          0  1.0  0.0000  0.8202
# 2871  3606.8  0.0370          0  0.0370          0  1.0  0.0000  0.8035
#
# [2872 rows x 8 columns]

# %%
df.head()
# Out:
#    #Depth     BVW  COAL_FLAG    PHIF  SAND_FLAG   SW   VCARB     VSH   KLOGH
# 0  3319.7  0.0200          0  0.0200          0  1.0  0.0120  0.7446  0.0010
# 1  3319.8  0.0200          0  0.0200          0  1.0  0.0000  0.7582  0.0010
# 2  3319.9  0.0200          0  0.0200          0  1.0  0.0339  0.5477  0.0017
# 3  3320.0  0.0238          0  0.0238          0  1.0  0.1487  0.4117  0.0306
# 4  3320.1  0.0413          0  0.0413          0  1.0  0.1526  0.3592  0.1252

# %%
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression().fit(X_train, y_train)

# %%
prediction=clf.predict(X_train)
from sklearn.metrics import r2_score
r2_score(y_train, prediction)
# Out:
# 0.042881788996594894

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import make_scorer
scoring = {'accuracy': make_scorer(accuracy_score), 'y_train': 'prediction'}

# %%
accuracy_score(y_train, prediction)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-a944a7be859d> in <module>()
# ----> 1 accuracy_score(y_train, prediction)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     183
#     184     # Compute accuracy for each possible representation
# --> 185     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     186     check_consistent_length(y_true, y_pred, sample_weight)
#     187     if y_type.startswith('multilabel'):
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      95     # No metrics support "multiclass-multioutput" format
#      96     if (y_type not in ["binary", "multiclass", "multilabel-indicator"]):
# ---> 97         raise ValueError("{0} is not supported".format(y_type))
#      98
#      99     if y_type in ["binary", "multiclass"]:
#
# ValueError: continuous is not supported

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_train, prediction)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-75-53c6fe5111a3> in <module>()
#       1 from sklearn.metrics import confusion_matrix
# ----> 2 confusion_matrix(y_train, prediction)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     266
#     267     """
# --> 268     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     269     if y_type not in ("binary", "multiclass"):
#     270         raise ValueError("%s is not supported" % y_type)
#
# /usr/local/lib/python3.6/dist-packages/sklearn/metrics/_classification.py in _check_targets(y_true, y_pred)
#      95     # No metrics support "multiclass-multioutput" format
#      96     if (y_type not in ["binary", "multiclass", "multilabel-indicator"]):
# ---> 97         raise ValueError("{0} is not supported".format(y_type))
#      98
#      99     if y_type in ["binary", "multiclass"]:
#
# ValueError: continuous is not supported

# %%
scoring = ['accuracy', 'precision']

# %%
scoring
# Out:
# ['accuracy', 'precision']
