# %%
>>> from sklearn import preprocessing
>>> le = preprocessing.LabelEncoder()
>>> le.fit([1, 2, 2, 6])
LabelEncoder()
>>> le.classes_
array([1, 2, 6])
>>> le.transform([1, 1, 2, 6])
array([0, 0, 1, 2]...)
>>> le.inverse_transform([0, 0, 1, 2])
array([1, 1, 2, 6])
# Out:
#   File "<ipython-input-1-bef3124349d5>", line 8
#     array([0, 0, 1, 2]...)
#                         ^
# SyntaxError: invalid syntax
