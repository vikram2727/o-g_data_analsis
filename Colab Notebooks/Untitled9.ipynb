# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-dbade227-669b-47dc-9e7a-8dce9c9f078e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dbade227-669b-47dc-9e7a-8dce9c9f078e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Book1.csv to Book1.csv

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5d741127-02d5-4039-bb7d-b634cd7ca1ac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5d741127-02d5-4039-bb7d-b634cd7ca1ac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Book2.csv to Book2.csv

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b3cb5423-1e83-404a-9a1f-01b7abf4f76d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b3cb5423-1e83-404a-9a1f-01b7abf4f76d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving permeability.csv to permeability.csv

# %%
from sklearn.model_selection import train_test_split

# %%
df1=pd.read_csv("Book1.csv")
df2= pd.read_csv("permeability.csv")
df3=pd.read_csv("Book2.csv")

# %%
df1.head()
# Out:
#         TVD     CALI       GR     LLD     LLS    NPHI    RHOB
# 0  827.6544  12.2811  19.1587  0.4839  0.1552  0.4637  1.8088
# 1  827.7595  12.2063  18.4251  0.4901  0.1551  0.4498  1.8524
# 2  827.8646  12.2179  16.5793  0.5016  0.1548  0.4574  1.9054
# 3  827.9698  12.1898  15.6918  0.4987  0.1553  0.4489  1.9441
# 4  828.0749  12.2659  16.5485  0.5105  0.1550  0.4206  1.9508

# %%
df2.head()
# Out:
#    K(md)
# 0    4.0
# 1    5.0
# 2    6.0
# 3    6.0
# 4    5.4

# %%
df3.head()
# Out:
#         TVD     CALI       GR     LLD     LLS    NPHI    RHOB
# 0  837.1166  13.1711  24.8632  3.1716  2.6669  0.2565  2.3436
# 1  837.2217  13.2292  28.2062  3.3238  2.7749  0.2515  2.3823
# 2  837.3268  13.2825  31.1763  3.5596  2.9598  0.2315  2.4120
# 3  837.4320  13.3605  32.8822  3.7076  3.1004  0.2119  2.4275
# 4  837.5371  13.4373  32.7572  3.6333  3.0756  0.2130  2.4257

# %%
X = df1

# %%
y = df2

# %%
import keras
import keras.backend as kb
import tensorflow as tf

# %%
model = keras.Sequential([
    keras.layers.Dense(32, activation=tf.nn.relu, input_shape=[7]),
    keras.layers.Dense(32, activation=tf.nn.relu),
    keras.layers.Dense(32, activation=tf.nn.relu),
    keras.layers.Dense(1)
  ])

# %%
optimizer = tf.keras.optimizers.RMSprop(0.0099)
model.compile(loss='mean_squared_error',optimizer='adam')
model.fit(df1,df2,epochs=500)

# %%
model.predict([df3])

# %%
model.compile(
  optimizer='sgd',
  loss='mse',
  metrics=[tf.keras.metrics.SparseTopKCategoricalAccuracy()])

# %%
tf.keras.metrics.CategoricalAccuracy(name="categorical_accuracy", dtype=None)
